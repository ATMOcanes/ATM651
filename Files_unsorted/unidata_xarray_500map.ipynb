# %% [markdown]
# Using Xarray for Data read and selection
# ========================================
#
# Use Xarray module to read in model data from nomads server.
#
# This example uses the xarray module to access data from the nomads server for
# archive NAM analysis data via OPeNDAP. Xarray makes it easier to select times
# and levels, although you still have to know the coordinate variable name. A
# simple 500 hPa plot is created after selecting with xarray.

# %% [markdown]
# Import all of our needed modules

# %%
from datetime import datetime

import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.pyplot as plt
import numpy as np
import scipy.ndimage as ndimage
import xarray as xr

# %% [markdown]
# Accessing data using Xarray
# ---------------------------

# %%
# Specify our date/time of product desired
dt = datetime(2016, 4, 16, 18)

# Construct our OPeNDAP access URL
base_url = 'https://www.ncei.noaa.gov/thredds/dodsC/model-namanl-old/'
data = xr.open_dataset(f'{base_url}{dt:%Y%m}/{dt:%Y%m%d}/'
                       f'namanl_218_{dt:%Y%m%d}_{dt:%H}00_000.grb',
                       decode_times=True)

# %% [markdown]
# NAM data is in a projected coordinate and you get back the projection
# X and Y values in km

# %%
# Create a 2-d meshgrid of our x, y coordinates
# manually converted to meters (km * 1000)
x, y = np.meshgrid(data['x'].values * 1000, data['y'].values * 1000)

# %% [markdown]
# Getting the valid times in a more useable format

# %%
# Get the valid times from the file
vtimes = []
for t in range(data.time.size):
    vtimes.append(datetime.utcfromtimestamp(data.time[t].data.astype('O') / 1e9))
print(vtimes)
# Out:
# [datetime.datetime(1970, 1, 1, 0, 0)]

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:                                                                                        (depth_below_surface: 1, height_above_ground: 1, height_above_ground1: 2, height_above_ground2: 1, height_above_ground3: 2, height_above_ground4: 2, hybrid: 1, isobaric: 39, isobaric1: 5, isobaric2: 42, layer_between_two_depths_below_surface_layer: 1, layer_between_two_depths_below_surface_layer1: 4, layer_between_two_depths_below_surface_layer1_bounds_1: 2, layer_between_two_depths_below_surface_layer2: 1, layer_between_two_depths_below_surface_layer2_bounds_1: 2, layer_between_two_depths_below_surface_layer_bounds_1: 2, layer_between_two_heights_above_ground_layer: 1, layer_between_two_heights_above_ground_layer1: 1, layer_between_two_heights_above_ground_layer1_bounds_1: 2, layer_between_two_heights_above_ground_layer_bounds_1: 2, layer_between_two_isobaric_layer: 1, layer_between_two_isobaric_layer_bounds_1: 2, layer_between_two_pressure_difference_from_ground_layer: 6, layer_between_two_pressure_difference_from_ground_layer1: 1, layer_between_two_pressure_difference_from_ground_layer1_bounds_1: 2, layer_between_two_pressure_difference_from_ground_layer2: 1, layer_between_two_pressure_difference_from_ground_layer2_bounds_1: 2, layer_between_two_pressure_difference_from_ground_layer_bounds_1: 2, layer_between_two_sigmas_layer: 1, layer_between_two_sigmas_layer_bounds_1: 2, time: 1, time1: 1, time_bounds_1: 2, x: 614, y: 428)
# Coordinates:
#   * x                                                                                              (x) float32 ...
#   * y                                                                                              (y) float32 ...
#   * time                                                                                           (time) float64 ...
#   * time1                                                                                          (time1) float64 ...
#   * layer_between_two_heights_above_ground_layer                                                   (layer_between_two_heights_above_ground_layer) float32 ...
#   * depth_below_surface                                                                            (depth_below_surface) float32 ...
#   * layer_between_two_pressure_difference_from_ground_layer                                        (layer_between_two_pressure_difference_from_ground_layer) float32 ...
#   * layer_between_two_depths_below_surface_layer                                                   (layer_between_two_depths_below_surface_layer) float32 ...
#   * height_above_ground                                                                            (height_above_ground) float32 ...
#   * height_above_ground1                                                                           (height_above_ground1) float32 ...
#   * height_above_ground2                                                                           (height_above_ground2) float32 ...
#   * layer_between_two_pressure_difference_from_ground_layer1                                       (layer_between_two_pressure_difference_from_ground_layer1) float32 ...
#   * isobaric                                                                                       (isobaric) float32 ...
#   * layer_between_two_isobaric_layer                                                               (layer_between_two_isobaric_layer) float32 ...
#   * isobaric1                                                                                      (isobaric1) float32 ...
#   * isobaric2                                                                                      (isobaric2) float32 ...
#   * layer_between_two_heights_above_ground_layer1                                                  (layer_between_two_heights_above_ground_layer1) float32 ...
#   * layer_between_two_depths_below_surface_layer1                                                  (layer_between_two_depths_below_surface_layer1) float32 ...
#   * hybrid                                                                                         (hybrid) float32 ...
#   * layer_between_two_pressure_difference_from_ground_layer2                                       (layer_between_two_pressure_difference_from_ground_layer2) float32 ...
#   * height_above_ground3                                                                           (height_above_ground3) float32 ...
#   * layer_between_two_depths_below_surface_layer2                                                  (layer_between_two_depths_below_surface_layer2) float32 ...
#   * height_above_ground4                                                                           (height_above_ground4) float32 ...
#   * layer_between_two_sigmas_layer                                                                 (layer_between_two_sigmas_layer) float32 ...
# Dimensions without coordinates: layer_between_two_depths_below_surface_layer1_bounds_1, layer_between_two_depths_below_surface_layer2_bounds_1, layer_between_two_depths_below_surface_layer_bounds_1, layer_between_two_heights_above_ground_layer1_bounds_1, layer_between_two_heights_above_ground_layer_bounds_1, layer_between_two_isobaric_layer_bounds_1, layer_between_two_pressure_difference_from_ground_layer1_bounds_1, layer_between_two_pressure_difference_from_ground_layer2_bounds_1, layer_between_two_pressure_difference_from_ground_layer_bounds_1, layer_between_two_sigmas_layer_bounds_1, time_bounds_1
# Data variables:
#     LambertConformal_Projection                                                                    int32 ...
#     reftime                                                                                        float64 ...
#     time_bounds                                                                                    (time, time_bounds_1) float64 ...
#     layer_between_two_heights_above_ground_layer_bounds                                            (layer_between_two_heights_above_ground_layer, layer_between_two_heights_above_ground_layer_bounds_1) float32 ...
#     layer_between_two_pressure_difference_from_ground_layer_bounds                                 (layer_between_two_pressure_difference_from_ground_layer, layer_between_two_pressure_difference_from_ground_layer_bounds_1) float32 ...
#     layer_between_two_depths_below_surface_layer_bounds                                            (layer_between_two_depths_below_surface_layer, layer_between_two_depths_below_surface_layer_bounds_1) float32 ...
#     layer_between_two_pressure_difference_from_ground_layer1_bounds                                (layer_between_two_pressure_difference_from_ground_layer1, layer_between_two_pressure_difference_from_ground_layer1_bounds_1) float32 ...
#     layer_between_two_isobaric_layer_bounds                                                        (layer_between_two_isobaric_layer, layer_between_two_isobaric_layer_bounds_1) float32 ...
#     layer_between_two_heights_above_ground_layer1_bounds                                           (layer_between_two_heights_above_ground_layer1, layer_between_two_heights_above_ground_layer1_bounds_1) float32 ...
#     layer_between_two_depths_below_surface_layer1_bounds                                           (layer_between_two_depths_below_surface_layer1, layer_between_two_depths_below_surface_layer1_bounds_1) float32 ...
#     layer_between_two_pressure_difference_from_ground_layer2_bounds                                (layer_between_two_pressure_difference_from_ground_layer2, layer_between_two_pressure_difference_from_ground_layer2_bounds_1) float32 ...
#     layer_between_two_depths_below_surface_layer2_bounds                                           (layer_between_two_depths_below_surface_layer2, layer_between_two_depths_below_surface_layer2_bounds_1) float32 ...
#     layer_between_two_sigmas_layer_bounds                                                          (layer_between_two_sigmas_layer, layer_between_two_sigmas_layer_bounds_1) float32 ...
#     Derived_radar_reflectivity_height_above_ground                                                 (time1, height_above_ground4, y, x) float32 ...
#     Derived_radar_reflectivity_hybrid                                                              (time1, hybrid, y, x) float32 ...
#     MaximumComposite_radar_reflectivity_entire_atmosphere                                          (time1, y, x) float32 ...
#     Radar_Echo_Top_183_DBZ_entire_atmosphere                                                       (time1, y, x) float32 ...
#     Liquid_volumetric_soil_moisture_non-frozen_layer_between_two_depths_below_surface_layer        (time1, layer_between_two_depths_below_surface_layer1, y, x) float32 ...
#     Number_of_soil_layers_in_root_zone_surface                                                     (time1, y, x) float32 ...
#     Wilting_point_surface                                                                          (time1, y, x) float32 ...
#     Transpiration_stress-onset_soil_moisture_surface                                               (time1, y, x) float32 ...
#     Direct_evaporation_cease_soil_moisture_surface                                                 (time1, y, x) float32 ...
#     Soil_porosity_surface                                                                          (time1, y, x) float32 ...
#     Pressure_surface                                                                               (time1, y, x) float32 ...
#     Pressure_maximum_wind                                                                          (time1, y, x) float32 ...
#     Pressure_tropopause                                                                            (time1, y, x) float32 ...
#     Pressure_height_above_ground                                                                   (time1, height_above_ground2, y, x) float32 ...
#     Temperature_surface                                                                            (time1, y, x) float32 ...
#     Temperature_tropopause                                                                         (time1, y, x) float32 ...
#     Temperature_layer_between_two_pressure_difference_from_ground_layer                            (time1, layer_between_two_pressure_difference_from_ground_layer, y, x) float32 ...
#     Temperature_height_above_ground                                                                (time1, height_above_ground1, y, x) float32 ...
#     Temperature_isobaric                                                                           (time1, isobaric, y, x) float32 ...
#     Latent_heat_net_flux_surface                                                                   (time1, y, x) float32 ...
#     Sensible_heat_net_flux_surface                                                                 (time1, y, x) float32 ...
#     Mean_Sea_Level_Pressure_NAM_Model_Reduction_msl                                                (time1, y, x) float32 ...
#     Surface_lifted_index_layer_between_two_isobaric_layer                                          (time1, layer_between_two_isobaric_layer, y, x) float32 ...
#     Best_4_layer_lifted_index_layer_between_two_pressure_difference_from_ground_layer              (time1, layer_between_two_pressure_difference_from_ground_layer2, y, x) float32 ...
#     Categorical_rain_yes1_no0_surface                                                              (time1, y, x) float32 ...
#     Categorical_freezing_rain_yes1_no0_surface                                                     (time1, y, x) float32 ...
#     Categorical_ice_pellets_yes1_no0_surface                                                       (time1, y, x) float32 ...
#     Categorical_snow_yes1_no0_surface                                                              (time1, y, x) float32 ...
#     Volumetric_soil_moisture_content_layer_between_two_depths_below_surface_layer                  (time1, layer_between_two_depths_below_surface_layer1, y, x) float32 ...
#     Convective_inhibition_surface                                                                  (time1, y, x) float32 ...
#     Convective_inhibition_layer_between_two_pressure_difference_from_ground_layer                  (time1, layer_between_two_pressure_difference_from_ground_layer2, y, x) float32 ...
#     Convective_Available_Potential_Energy_surface                                                  (time1, y, x) float32 ...
#     Convective_Available_Potential_Energy_layer_between_two_pressure_difference_from_ground_layer  (time1, layer_between_two_pressure_difference_from_ground_layer2, y, x) float32 ...
#     Turbulent_Kinetic_Energy_isobaric                                                              (time1, isobaric, y, x) float32 ...
#     Dew_point_temperature_height_above_ground                                                      (time1, height_above_ground, y, x) float32 ...
#     Surface_wind_gust_surface                                                                      (time1, y, x) float32 ...
#     Lightning_surface                                                                              (time1, y, x) float32 ...
#     Storm_relative_helicity_layer_between_two_heights_above_ground_layer                           (time1, layer_between_two_heights_above_ground_layer, y, x) float32 ...
#     Pressure_reduced_to_MSL_msl                                                                    (time1, y, x) float32 ...
#     Visibility_surface                                                                             (time1, y, x) float32 ...
#     downward_short_wave_rad_flux_surface                                                           (time1, y, x) float32 ...
#     downward_long_wave_rad_flux_surface                                                            (time1, y, x) float32 ...
#     Moisture_availability_layer_between_two_depths_below_surface_layer                             (time1, layer_between_two_depths_below_surface_layer2, y, x) float32 ...
#     upward_short_wave_rad_flux_surface                                                             (time1, y, x) float32 ...
#     upward_long_wave_rad_flux_surface                                                              (time1, y, x) float32 ...
#     Planetary_boundary_layer_height_surface                                                        (time1, y, x) float32 ...
#     Plant_canopy_surface_water_surface                                                             (time1, y, x) float32 ...
#     Soil_type_as_in_Zobler_surface                                                                 (time1, y, x) float32 ...
#     Vegitation_type_as_in_SiB_surface                                                              (time1, y, x) float32 ...
#     Blackadar's_mixing_length_scale_hybrid                                                         (time1, hybrid, y, x) float32 ...
#     Snow_cover_surface                                                                             (time1, y, x) float32 ...
#     Parcel_lifted_index_to_500_hPa_layer_between_two_pressure_difference_from_ground_layer         (time1, layer_between_two_pressure_difference_from_ground_layer1, y, x) float32 ...
#     Drag_coefficient_surface                                                                       (time1, y, x) float32 ...
#     Friction_velocity_surface                                                                      (time1, y, x) float32 ...
#     u-component_of_wind_tropopause                                                                 (time1, y, x) float32 ...
#     u-component_of_wind_maximum_wind                                                               (time1, y, x) float32 ...
#     u-component_of_wind_PBLRI                                                                      (time1, y, x) float32 ...
#     u-component_of_wind_layer_between_two_pressure_difference_from_ground_layer                    (time1, layer_between_two_pressure_difference_from_ground_layer, y, x) float32 ...
#     u-component_of_wind_height_above_ground                                                        (time1, height_above_ground3, y, x) float32 ...
#     u-component_of_wind_isobaric                                                                   (time1, isobaric, y, x) float32 ...
#     v-component_of_wind_tropopause                                                                 (time1, y, x) float32 ...
#     v-component_of_wind_maximum_wind                                                               (time1, y, x) float32 ...
#     v-component_of_wind_PBLRI                                                                      (time1, y, x) float32 ...
#     v-component_of_wind_layer_between_two_pressure_difference_from_ground_layer                    (time1, layer_between_two_pressure_difference_from_ground_layer, y, x) float32 ...
#     v-component_of_wind_height_above_ground                                                        (time1, height_above_ground3, y, x) float32 ...
#     v-component_of_wind_isobaric                                                                   (time1, isobaric, y, x) float32 ...
#     Vertical_velocity_pressure_isobaric                                                            (time1, isobaric, y, x) float32 ...
#     Vertical_velocity_geometric_isobaric                                                           (time1, isobaric2, y, x) float32 ...
#     Absolute_vorticity_isobaric                                                                    (time1, isobaric1, y, x) float32 ...
#     Vertical_u-component_shear_layer_between_two_heights_above_ground_layer                        (time1, layer_between_two_heights_above_ground_layer1, y, x) float32 ...
#     Vertical_v-component_shear_layer_between_two_heights_above_ground_layer                        (time1, layer_between_two_heights_above_ground_layer1, y, x) float32 ...
#     Specific_humidity_height_above_ground                                                          (time1, height_above_ground1, y, x) float32 ...
#     Relative_humidity_zeroDegC_isotherm                                                            (time1, y, x) float32 ...
#     Relative_humidity_layer_between_two_pressure_difference_from_ground_layer                      (time1, layer_between_two_pressure_difference_from_ground_layer, y, x) float32 ...
#     Relative_humidity_height_above_ground                                                          (time1, height_above_ground, y, x) float32 ...
#     Relative_humidity_layer_between_two_sigmas_layer                                               (time1, layer_between_two_sigmas_layer, y, x) float32 ...
#     Relative_humidity_isobaric                                                                     (time1, isobaric, y, x) float32 ...
#     Precipitable_water_entire_atmosphere                                                           (time1, y, x) float32 ...
#     Total_precipitation_surface_0_Hour_Accumulation                                                (time, y, x) float32 ...
#     Convective_precipitation_surface_0_Hour_Accumulation                                           (time, y, x) float32 ...
#     Water_equiv_of_accum_snow_depth_surface_0_Hour_Accumulation                                    (time, y, x) float32 ...
#     Water_equiv_of_accum_snow_depth_surface                                                        (time1, y, x) float32 ...
#     Snow_depth_surface                                                                             (time1, y, x) float32 ...
#     Geopotential_height_LLTW                                                                       (time1, y, x) float32 ...
#     Geopotential_height_surface                                                                    (time1, y, x) float32 ...
#     Geopotential_height_cloud_base                                                                 (time1, y, x) float32 ...
#     Geopotential_height_zeroDegC_isotherm                                                          (time1, y, x) float32 ...
#     Geopotential_height_PBLRI                                                                      (time1, y, x) float32 ...
#     Geopotential_height_isobaric                                                                   (time1, isobaric, y, x) float32 ...
#     Total_cloud_cover_entire_atmosphere                                                            (time1, y, x) float32 ...
#     Land_cover_land1_sea0_surface                                                                  (time1, y, x) float32 ...
#     Surface_roughness_surface                                                                      (time1, y, x) float32 ...
#     Albedo_surface                                                                                 (time1, y, x) float32 ...
#     Soil_temperature_layer_between_two_depths_below_surface_layer                                  (time1, layer_between_two_depths_below_surface_layer1, y, x) float32 ...
#     Soil_temperature_depth_below_surface                                                           (time1, depth_below_surface, y, x) float32 ...
#     Soil_moisture_content_layer_between_two_depths_below_surface_layer                             (time1, layer_between_two_depths_below_surface_layer, y, x) float32 ...
#     Vegetation_surface                                                                             (time1, y, x) float32 ...
#     Ice_cover_ice1_no_ice0_surface                                                                 (time1, y, x) float32 ...
#     Missing_surface                                                                                (time1, y, x) float32 ...
#     Missing_PBLRI                                                                                  (time1, y, x) float32 ...

# %% [markdown]
# Xarray has some nice functionality to choose the time and level that
# you specifically want to use. In this example the time variable is 'time' and
# the level variable is 'isobaric1'. Unfortunately, these can be different with
# each file you use, so you'll always need to check what they are by listing
# the coordinate variable names

# %%
# print(data.Geopotential_height.coords)
hght_500 = data['Geopotential_height_isobaric'].sel(isobaric=500)
uwnd_500 = data['u-component_of_wind_isobaric'].sel(isobaric=500)
vwnd_500 = data['v-component_of_wind_isobaric'].sel(isobaric=500)

# %%
# print(data.Geopotential_height.coords) # TIME DOESNT WORK
#hght_500 = data['Geopotential_height_isobaric'].sel(time1=vtimes[0], isobaric=500)
#uwnd_500 = data['u-component_of_wind_isobaric'].sel(time1=vtimes[0], isobaric=500)
#vwnd_500 = data['v-component_of_wind_isobaric'].sel(time1=vtimes[0], isobaric=500)

# %% [markdown]
# Now make the 500-hPa map
# ------------------------

# %%
# Must set data projection, NAM is LCC projection
datacrs = ccrs.LambertConformal(
    central_latitude=data.LambertConformal_Projection.latitude_of_projection_origin,
    central_longitude=data.LambertConformal_Projection.longitude_of_central_meridian)

# A different LCC projection for the plot.
plotcrs = ccrs.LambertConformal(central_latitude=45., central_longitude=-100.,
                                standard_parallels=[30, 60])

fig = plt.figure(figsize=(17., 11.))
ax = plt.axes(projection=plotcrs)
ax.coastlines('50m', edgecolor='black')
ax.add_feature(cfeature.STATES, linewidth=0.5)
ax.set_extent([-130, -67, 20, 50], ccrs.PlateCarree())

clev500 = np.arange(5100, 6000, 60)
cs = ax.contour(x, y, ndimage.gaussian_filter(hght_500, sigma=5), clev500,
                colors='k', linewidths=2.5, linestyles='solid', transform=datacrs)
ax.clabel(cs, fontsize=12, colors='k', inline=1, inline_spacing=8,
          fmt='%i', rightside_up=True, use_clabeltext=True)

# Here we put boxes around the clabels with a black boarder white facecolor
# `labelTexts` necessary as ~cartopy.mpl.contour.GeoContourSet.clabel
# does not return list of texts as of 0.18
for t in cs.labelTexts:
    t.set_bbox({'fc': 'w'})

# Transform Vectors before plotting, then plot wind barbs.
ax.barbs(x, y, uwnd_500.data, vwnd_500.data, length=7, regrid_shape=20, transform=datacrs)

# Add some titles to make the plot readable by someone else
plt.title('500-hPa Geopotential Heights (m)', loc='left')
plt.title(f'VALID: {vtimes[0]}', loc='right');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-1efddd216a8e> in <module>
#       1 # Must set data projection, NAM is LCC projection
#       2 datacrs = ccrs.LambertConformal(
# ----> 3     central_latitude=data.LambertConformal_Projection.latitude_of_projection_origin,
#       4     central_longitude=data.LambertConformal_Projection.longitude_of_central_meridian)
#       5
#
# ~/opt/miniconda3/lib/python3.7/site-packages/xarray/core/common.py in __getattr__(self, name)
#     227                     return source[name]
#     228         raise AttributeError(
# --> 229             "{!r} object has no attribute {!r}".format(type(self).__name__, name)
#     230         )
#     231
#
# AttributeError: 'DataArray' object has no attribute 'latitude_of_projection_origin'

# %%
data.LambertConformal_Projection
# Out:
# <xarray.DataArray 'LambertConformal_Projection' ()>
# array(0, dtype=int32)
