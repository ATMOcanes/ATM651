# %% [markdown]
# # Analysis and assimilation of v200
# ## NASA GMAO MERRA system
# ### 2008-05-14 complex trough and severe weather outbreak

# %% [markdown]
# IDV zipped bundle is [here](http://weather.rsmas.miami.edu/repository/entry/show?entryid=aa5e926c-c70a-45fb-b44b-3d7910b0f637). [Severe weather reports.](https://www.spc.noaa.gov/climo/reports/080514_rpts.html) Looks like some aircraft exclusions even, in the heart of it, but profiler and raobs are there.

# %%
# %reload_ext ipyidv

# %%
# %make_image -capture legend -caption 'Time of biggest AT and o-f'

# %%
# %make_image -capture legend -caption 'Similar pattern 6 hours later'

# %%
# %make_image -capture legend -caption 'Telling that trough to split, extend, deepen'

# %%
# %make_image -capture legend -caption 'Strongly opposing the dynamical tendency'

# %%
# %make_image -capture legend -caption 'AT is strongly opposing the dynamical tendency'

# %%
# %make_image -capture legend -caption 'Similar pattern the next day too (12-18Z)'

# %%
# !date
# Out:
# Mon Oct 25 13:23:53 EDT 2021
