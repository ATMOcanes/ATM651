# %% [markdown]
# # Latitude excursions in June 2008 trajectories
#
# ### Brian Mapes and Suvarchal Cheedela who did the calculations
#
# #### dataset at https://weather.rsmas.miami.edu/repository/entry/show?entryid=e58bedf7-3ad0-4f9c-bf4f-7edea21755b6

# %%
import xarray as xr

# %%
ds = xr.open_dataset('https://weather.rsmas.miami.edu/repository/opendap/e58bedf7-3ad0-4f9c-bf4f-7edea21755b6/entry.das')
# Out:
# /Users/brianmapes/opt/miniconda3/envs/barotropic/lib/python3.10/site-packages/xarray/coding/times.py:150: SerializationWarning: Ambiguous reference date string: 1-1-1 00:00:0.0. The first value is assumed to be the year hence will be padded with zeros to remove the ambiguity (the padded reference date string is: 0001-1-1 00:00:0.0). To remove this message, remove the ambiguity by padding your reference date strings with zeros.
#   warnings.warn(warning_msg, SerializationWarning)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:        (time: 30, level: 17, lat: 73, lon: 144, tlev: 4)
# Coordinates:
#   * time           (time) datetime64[ns] 2008-06-01 2008-06-02 ... 2008-06-30
#   * level          (level) float32 1e+03 925.0 850.0 700.0 ... 30.0 20.0 10.0
#   * lat            (lat) float32 90.0 87.5 85.0 82.5 ... -82.5 -85.0 -87.5 -90.0
#   * lon            (lon) float32 0.0 2.5 5.0 7.5 ... 350.0 352.5 355.0 357.5
#   * tlev           (tlev) float32 10.0 3e+03 5e+03 7e+03
# Data variables: (12/33)
#     U              (time, level, lat, lon) float32 ...
#     latlocs0dayF   (time, tlev, lat, lon) float32 ...
#     lonlocs0dayF   (time, tlev, lat, lon) float32 ...
#     latlocs1dayF   (time, tlev, lat, lon) float32 ...
#     lonlocs1dayF   (time, tlev, lat, lon) float32 ...
#     latlocs2dayF   (time, tlev, lat, lon) float32 ...
#     ...             ...
#     rcindex1dayF   (time, tlev, lat, lon) float32 ...
#     rcindex1dayB   (time, tlev, lat, lon) float32 ...
# ...

# %%
(ds.latlocs3dayB[0][0]).plot()

# %%
# quick view at 10m altitude level at first time, June 1 2008

(ds.latlocs3dayF[0][0]-ds.latlocs3dayB[0][0]).plot()

# %%
(ds.latlocs3dayF[:][0]-ds.latlocs3dayB[:][0]).plot(bins=100)
# Out:
# (array([1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 1.000e+00, 0.000e+00,
#         1.000e+00, 2.000e+00, 1.000e+00, 1.000e+00, 6.000e+00, 5.000e+00,
#         0.000e+00, 5.000e+00, 8.000e+00, 6.000e+00, 1.200e+01, 1.500e+01,
#         2.500e+01, 2.700e+01, 3.300e+01, 5.200e+01, 5.900e+01, 8.600e+01,
#         1.080e+02, 1.080e+02, 1.600e+02, 1.730e+02, 1.810e+02, 2.170e+02,
#         2.370e+02, 3.120e+02, 2.670e+02, 3.970e+02, 4.320e+02, 4.370e+02,
#         4.850e+02, 5.330e+02, 5.470e+02, 6.490e+02, 6.680e+02, 7.300e+02,
#         8.150e+02, 9.180e+02, 1.125e+03, 1.089e+03, 1.154e+03, 1.300e+03,
#         1.297e+03, 1.385e+03, 1.510e+03, 1.588e+03, 1.641e+03, 1.477e+03,
#         1.528e+03, 1.423e+03, 1.337e+03, 1.301e+03, 1.258e+03, 1.216e+03,
#         1.108e+03, 1.068e+03, 9.920e+02, 8.570e+02, 8.060e+02, 7.190e+02,
#         7.540e+02, 6.650e+02, 5.630e+02, 5.710e+02, 5.090e+02, 4.320e+02,
#         4.040e+02, 3.770e+02, 3.470e+02, 2.900e+02, 2.260e+02, 2.280e+02,
# ...
