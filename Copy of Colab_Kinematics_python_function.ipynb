# %% [markdown]
# <a name="top"></a>
#
# # Kinematics: the elements of 2D vector fields
# ## (linearly varying flow patterns)
# ### Brian Mapes, University of Miami
#
# ### **Assignment: Make it read well from top to bottom.**
# This requires learing (from examples) how to write LaTeX mathematics and other good-looking Markdown, how to write code that executes, and how to capture images from the IDV. Please do not leave my dumb place-holder labels like xxx or ???. Please take the time, step by step, to make it a readable document of high quality.
#
# ### Exercises
# ### Part 1:
# 1. <a href="#Exercise1">A little bit of math</a>
# 1. <a href="#Exercise2">Display the 4 basic fields: div, vort, def1, def2</a>
# 1. <a href="#Exercise3">Simple sum of vort and def</a>
# 1. <a href="#Exercise4">Simple sum of vort and U</a>
# 1. <a href="#Exercise5">Simple sum that interests you</a>
#
# <a href="#Part2">Part 2: Examine real flow patterns</a>
#
# 6. <a href="#Exercise56">Show images of almost-pure div, vort, def</a>
#
# <hr style="height:2px;">
#
# ### Background
# **Kinematics** is not dynamics, it is just a *description* of how 2D vector fields $\vec V_{2D}$ = **V** = \<u,v\> vary in a 2D space with Cartesian coordinates x,y.
#
# * Consider all possible LINEAR dependences of **V** = \<u,v\> on space (x,y) around an origin (0,0)
#     * Measured by 4 coefficients $c_1, c_2, c_3, c_4$
# * Also, add a constant (that is, not varying with x,y) vector field U,V.
#
# In other words, our *displayed* vector field V(x,y) = {u,v}(x,y) is:
#
# $$ u_{disp} = U + c_1 x  +c_2 y$$
# $$ v_{disp} = V + c_3 x  +c_4 y$$
#
#
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise1"></a>
#
# #Exercise 1: enter your answers below.
#
# 1. Show that divergence is $c_1 + c_4$.
#
# 2. Show that vorticity is $c_3 - c_2$.
#
# 3. What are the other 2 combinations? def1 = **???** and def2 = **???**. These are deformation patterns with *no vorticity and no divergence*. (The code in cells below defines them as they are used in this notebook.)
#
# Enter your answers in the cell below, learning how to write markdown LaTeX equations from the examples given.

# %% [markdown]
# ## Exercise 1 Answer:
# * $ div = \frac{\partial u}{\partial x} + \frac{\partial v}{\partial y}= c_1+c_4$
# * $ \zeta_{rel} = \frac{\partial v}{\partial x} - \frac{\partial u}{\partial y} = c_3-c_2$
# * $ Def_{Div} = \frac{\partial u}{\partial x} - \frac{\partial v}{\partial y} = c_1-c_4$
# * $ Def_{Vort} = \frac{\partial v}{\partial x} + \frac{\partial u}{\partial y} = c_3+c_2$

# %% [markdown]
# <a href="#top">Top</a>

# %% [markdown]
# <a name="Exercise2"></a>
# ## Exercise 2: Create and display the basic fields in Python
# * The first code cell (shift-return to execute it and move on) sets up a coordinate system (x,y) from -10 to 10.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Set up a coordinate grid centered on 0,0
n = 10
x,y = np.mgrid[-n:n+1, -n:n+1]

# %% [markdown]
# * Now define the basic set of "pure" div, vort, def1, def2, and a mean flow in the x or y directions (U, V).
# * Note that each field has a u and a v component indicated by the first letter
#   * like udiv and vvor and uV=0 and vU=0
# * Notice that both components are set on one line using the comma **,**
# * Study these names and understand their logic, You will need it, in order to construct sums of these in the cells below.
# * Finally, execute the cell that displays the vector fields as arrows using the *quiver* function.
# * The first one has been done for you, then you complete the work for the other cases by example.

# %%
# Pure divergence of unit magnitude
udiv,vdiv = 1*x, 1*y

# Pure vorticity of unit magnitude
uvor,vvor = -1*y, 1*x

# Pure def1 of unit magnitude
udef1,vdef1 = 1*x, -1*y

# Pure def2 of unit magnitude
udef2,vdef2 = 1*y, 1*x

# Pure U and V
uU, vU = 1, 0
uV, vV = 0, 1

# %%
# a helper function to make the standard plot 
def plotquiver(udisp,vdisp,label):
  fig, ax = plt.subplots(figsize=(7,7))
  plt.quiver(x, y, udisp, vdisp, pivot='mid')
  plt.title(label)
  plt.show()

# %% [markdown]
# # First combination: pure divergence, plus a little mean U wind

# %%
# Define the display field udisp,vdisp and give it a label. 

udisp,vdisp = udiv + 2*uU, vdiv + 2*vU
label = 'pure div strength 1 plus U=2'
plotquiver(udisp,vdisp,label)

# %% [markdown]
# #Pure vorticity

# %%
# Define the display field udisp,vdisp and give it a label. 

udisp,vdisp = uvor,vvor
label = 'Pure unit vorticity'
plotquiver(udisp,vdisp,label)

# %% [markdown]
# # Pure deformation type 1

# %%
# Define the display field udisp,vdisp and give it a label. 

udisp,vdisp = udef1,vdef1
label = 'Pure unit def1'
plotquiver(udisp,vdisp,label)

# %% [markdown]
# # Pure deformation type 2

# %%
# Define the display field udisp,vdisp and give it a label. 

udisp,vdisp = udef2,vdef2
label = 'Pure unit def2'
plotquiver(udisp,vdisp,label)

# %% [markdown]
# # Sum of def1 + def2 (equal parts, or 2 to 1, or 1 to 2). Experiment!

# %%
# Define the display field udisp,vdisp and give it a label. 

udisp,vdisp = udef1+udef2,vdef1+vdef2
label = '1*def1 + 1*def2'
plotquiver(udisp,vdisp,label)

# %% [markdown]
# # Sum of vorticity plus deformation in equal measure
#
# Note that these are two curved flow patterns. Together they makes a flow we could describe as diagonal shear, or where 2 fronts meet.

# %%
udisp,vdisp = uvor+udef1+0*udef2,vvor+vdef1+0*vdef2
label = 'vorticity plus deformation'
plotquiver(udisp,vdisp,label)

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise3"></a>
# # Exercise 3:
#
# What are the **units and typical magnitude in the atmosphere** of these horizontal kinematic quantities (divergence, vorticity, deformation)?
#
# To answer this, suppose u,v are in m/s (-10 to 10 range of values), and x,y are in 100s of km (so the *quiver* plots are about 2000 km across). You can just estimate the order of magnitude of any one of the derivatives (or a coefficient $c_1, c_2, c_3, c_4$). Express your answer using seconds as the time unit, and then convert to days as the time unit.  (You may take $1 day \simeq 10^5 s$ for convenience)

# %% [markdown]
# # Answer 3:
#
# Typical values of the top and bottom of one of these kinematic derivative components are:
# $\delta u \simeq 10 m/s$
#
# $\delta x \simeq 1000 km$
#
# Therefore, the typical value $\delta u / \delta x$ is $10^{-2} \frac{1}{s}$ or $10^3 \frac{1}{day}$.

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise4"></a>
#
# ## Exercise 4: Pure vor, plus U of various strengths
#
# Notice that this is like looking at different altitudes, in a flow made up of a cyclone (same at all levels) plus more and more of a westerly wind increasing with height, like in midlatitudes because of the equator-to-pole temperature gradient. In your description, try to describe the flows in the ways we describe weather systems in the atmosphere (closed highs and lows, or troughs and ridges).

# %%
# Define the display field udisp,vdisp and give it a label. 

udisp,vdisp =uvor+10*uU,vvor 
label = 'Pure vortex, plus U of strength 10: a trough'
plotquiver(udisp,vdisp,label)

# %% [markdown]
# ## Answer to Exercise 4:
#
# Vorticity plus straight flow can be described as ...
#
# At lower levels,  it is a cyclone
#
# At upper levels, with more mean westerly flow, it is trough or ridge depending on pressure levels

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Exercise5"></a>
#
# ## 5. Make a combination that interests YOU.
#
# Tinker with it to make something relevant to weather patterns. One example might be combining vor plus negative div for example, like in a cyclone with some frictional inflow. Be creative!

# %%
# Define the display field udisp,vdisp and give it a label. 
# Edit-> Copy and paste this cell, then adjust the top 2 lines for the other cases

udisp,vdisp = uvor-udiv,vvor-vdiv
label = 'My combination: vorticity plus negative divergence'
plotquiver(udisp,vdisp,label)

# %% [markdown]
# ## Answer to Exercise 5:
# **Relate the image verbally to a weather situation.**
#
# My example shows that when you combine vorticity and negative divergence you get a cyclone with a low pressure center that sucks surrounding air into the eye
#
# *Copy the Share link at the top and send to me (or maybe we will just look at them in class and be done)*

# %% [markdown]
# <a href="#top">Top</a>
# <hr style="height:2px;">

# %% [markdown]
# <a name="Part2"></a>
#
# # Part 2: IDV studies of actual weather flow fields
#
# To do this part, install the [nightly IDV](https://www.unidata.ucar.edu/downloads/idv/nightly/index.jsp), then add my Customized --> Mapes IDV collection plugin, from the Plugin Manager, as shown:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After you do that and relaunch, you will have the MapesIDV folder in the toolbar as shown. From that, pull down and select Def-Div-Vor-Global as shown here:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# That will give you a global display of 200 hPa (upper troposphere) winds, along with their divergent vs. rotational breakdown, each of which is described by a scalar function (velocity potential $\chi$ and streamfunction $\psi$). The Laplacian (second derivative in 2D) of these is the divergence and vorticity, respectively. Play with the displays and get familiar with them.

# %% [markdown]
# Of course there are 4 derivative quantities one can make to express local variations of u & v in x & y (linear, that is the calculus limit: *everything varies linearly, if you look locally enough*). Divergence and vorticity are two combinations of these, and the remaining two are called deformation (which obeys no useful equations, to my knowledge). There is along-the grid deformation of both signs, and 45-degree-to-grid deformation of both signs. The geometric mean is total deformation. These quantities are illustrated below.

# %% [markdown]
# ## The two "components" of deformation on a grid: along (+/-) and 45deg (+/-)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <a name="Exercise6"></a>
#
# # Assignment (exercise 6):
# ## Find 3 places that approximate the 'pure' cases of div, rot, def1, def2, or the combinations you built in Part 1 above.
# ### Capture and annotate and explain images showing how the flow arrows look there.
# You can view the globe from all 6 directions using the blue-sided cubes at upper left, rotate the globe with the green curl arrow, and zoom in and out and pan, all using the controls along the left edge of the View Window. Mouse shortcuts exist too: Help menu has Zooming and Panning instructions conveniently set apart from all the other documentation. You can change the altitude (look at the lower troposphere, or the stratosphere) on any display by clicking its blue link in the Legend, and changing the level in the Display Control.
#
# You can paste images into a Text cell (gibberish appears), then shift-return will execute that gibberish code that displays the image. Use a different text cell for your comments.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Observing the divergence off the northwestern coast of Australia, I see a region of very slow windspeed and thus close to zero divergence. Shifting my gaze over the landmass I can see a region where the streamlines exhibit very slight confluence and thus a slight, negative divergence.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Observing the same scene but with an eye for vorticity, I can see how the shear and particularly the curvature over the landmass play a significant role in a positive vorticity. The same region I observed earlier as having zero divergence now has a very slight vorticity due to the differing directions of the weak winds.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Observing the same region yet again, but inspecting the $45^o$ deformation, I can see how my vorticity takes on an opposite value for my deformation. My blue regions are now red, and vise versa.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# This rapid change in windspeed and wind direction off the southeastern coast of south america creates an interesting pattern for my divergence. The stretching followed by contraction shows two regions of positive and negative divergence almost touching one another.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Of course, the intense curvature of the last location also creates an interesting image for my vorticity, revealing a region of positive curvature followed immediately by negative curvature.

# %% [markdown]
# ![image.png](attachment:image.png)
# And as expected, this region creates an opposite affect for the sign of my deformation along the $45^o$ axis
